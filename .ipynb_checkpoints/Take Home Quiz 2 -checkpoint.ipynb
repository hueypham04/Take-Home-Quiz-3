# %%
import pandas as pd
import matplotlib as mpl
dataset=pd.read_csv("C:/Users/pc/Downloads/student_results.csv")

# %%
dataset.head(15)
# Out:
#     ID number  Assessment 1  Assessment 2  Online quiz 1   Online quiz 2  \
# 0    54002768         17.21         24.19            0.00           0.00
# 1    54005658         66.50          0.00           22.00          18.14
# 2    54010438          0.00          0.00            0.00           0.00
# 3    54011658         60.67         29.07           27.50          18.40
# 4    54012789         37.33         29.01           11.00          20.00
# 5    54013792         47.44         27.23           15.00          18.71
# 6    54018502         69.30         26.83           25.00          17.76
# 7    54020391         66.89          0.00           24.00          19.50
# 8    54020678         19.25         27.12           10.50          19.31
# 9    54030996          0.00         28.17            0.00           0.00
# 10   54031400         64.56         27.68           27.19          19.99
# 11   54055936         70.00         29.42           17.00          19.40
# ...

# %%
dataset.isnull().any()
# Out:
# ID number             False
# Assessment 1          False
# Assessment 2          False
# Online quiz 1         False
# Online quiz 2         False
# Online quiz 3         False
# Online quiz 4         False
# Group assignment 1    False
# Group assignment 2    False
# Assessment 3          False
# Assessment 4          False
# Group assignment 3    False
#  Group evaluation     False
# Final exam            False
# Class No              False
# groupname             False
# Student category      False
# dtype: bool

# %%
dataset.fillna(0)
# Out:
#      ID number  Assessment 1  Assessment 2  Online quiz 1   Online quiz 2  \
# 0     54002768         17.21         24.19            0.00           0.00
# 1     54005658         66.50          0.00           22.00          18.14
# 2     54010438          0.00          0.00            0.00           0.00
# 3     54011658         60.67         29.07           27.50          18.40
# 4     54012789         37.33         29.01           11.00          20.00
# 5     54013792         47.44         27.23           15.00          18.71
# 6     54018502         69.30         26.83           25.00          17.76
# 7     54020391         66.89          0.00           24.00          19.50
# 8     54020678         19.25         27.12           10.50          19.31
# 9     54030996          0.00         28.17            0.00           0.00
# 10    54031400         64.56         27.68           27.19          19.99
# 11    54055936         70.00         29.42           17.00          19.40
# ...

# %%
dataset['Total_marks']=(((dataset['Assessment 1']/70)*100)*0.07+
             ((dataset['Assessment 2']/30)*100)*0.03+
             ((dataset['Assessment 3']/70)*100)*0.07+
             ((dataset['Assessment 4']/30)*100)*0.03+
            ((dataset['Online quiz 1 ']/30)*100)*0.03+
            ((dataset['Online quiz 2']/20)*100)*0.02+
            ((dataset['Online quiz 3']/30)*100)*0.03+
            ((dataset['Online quiz 4']/20)*100)*0.02+
            ((dataset['Group assignment 1']/30)*100)*0.024+
            ((dataset['Group assignment 2']/20)*100)*0.016+
            ((dataset['Group assignment 3']/50)*100)*0.04+
            ((dataset[' Group evaluation']/2)*100)*0.02+
            ((dataset['Final exam']/100)*100)*0.6)
dataset.head(5)
# Out:
#    ID number  Assessment 1  Assessment 2  Online quiz 1   Online quiz 2  \
# 0   54002768         17.21         24.19             0.0           0.00
# 1   54005658         66.50          0.00            22.0          18.14
# 2   54010438          0.00          0.00             0.0           0.00
# 3   54011658         60.67         29.07            27.5          18.40
# 4   54012789         37.33         29.01            11.0          20.00
#
#    Online quiz 3  Online quiz 4  Group assignment 1  Group assignment 2  \
# 0          15.00          18.92               26.57                0.00
# 1          29.00          19.91               22.35               17.04
# 2           4.13           0.00               18.86                0.00
# 3          24.50          18.52               25.00               19.29
# 4          19.50          19.10               27.75               17.82
#
#    Assessment 3  Assessment 4  Group assignment 3   Group evaluation  \
# ...

# %%
dataset2=dataset[['Total_marks','Student category']]
dataset2.boxplot(by='Student category')

# %%
dataset3=dataset['Total_marks'].groupby(dataset['Class No'])
dataset3.var()
# Out:
# Class No
# 1     242.710561
# 2     160.151821
# 3     273.495919
# 4     319.034109
# 5     383.676678
# 6     252.025294
# 7     344.554792
# 8     358.580091
# 9     205.356479
# 10    286.748324
# 11    333.302820
# 12    239.145724
# 15    221.097589
# 16    179.019517
# 17    238.727958
# 18    242.163125
# 19     95.438828
# 20    210.342787
# 21    247.260917
# Name: Total_marks, dtype: float64

# %%
dataset3.describe()
# Out:
#           count       mean        std      min       25%      50%       75%  \
# Class No
# 1          30.0  59.280813  15.579171  14.8550  51.07025  56.7792  68.60760
# 2          29.0  60.671069  12.655110  22.6042  54.83040  59.5680  66.02360
# 3          30.0  57.610713  16.537712  17.0968  49.74305  57.7445  65.73395
# 4          29.0  56.220069  17.861526  12.1400  52.02240  59.1370  63.59660
# 5          33.0  57.918085  19.587666  18.3944  50.04200  56.2168  67.82600
# 6          33.0  62.332600  15.875305  27.4430  56.57060  60.9042  72.05440
# 7          31.0  54.879626  18.562187  16.5880  43.41350  53.4312  63.86460
# 8          33.0  54.384800  18.936211  13.3912  47.41720  56.0310  64.55240
# 9          32.0  53.918419  14.330264  27.9994  45.27115  50.2518  59.31065
# 10         29.0  59.459821  16.933645  15.0680  50.46640  60.3250  68.22940
# 11         28.0  53.123421  18.256583  13.8550  39.17830  56.1716  61.04240
# ...

# %%
bin=[0,50,65,75,85,100]
dataset['Grade'] = pd.cut(dataset['Total_marks'],bin, 
               labels=["Fail", "Pass", "Credit", "Distinction","High Distinction"])
dataset['Grade'].head(10)
# Out:
# 0           Pass
# 1         Credit
# 2           Fail
# 3    Distinction
# 4           Fail
# 5           Pass
# 6         Credit
# 7           Fail
# 8           Fail
# 9           Fail
# Name: Grade, dtype: category
# Categories (5, object): [Fail < Pass < Credit < Distinction < High Distinction]

# %%
import statsmodels.api as sm
model = sm.OLS(dataset['Final exam'], dataset['Assessment 1']).fit()

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Final exam   R-squared:                       0.801
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     2325.
# Date:                Thu, 17 May 2018   Prob (F-statistic):          1.46e-204
# Time:                        21:05:51   Log-Likelihood:                -2654.8
# No. Observations:                 578   AIC:                             5312.
# Df Residuals:                     577   BIC:                             5316.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm
X = dataset["Assessment 1"] 
y = dataset["Final exam"] 
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Final exam   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     61.55
# Date:                Thu, 17 May 2018   Prob (F-statistic):           2.11e-14
# Time:                        21:05:51   Log-Likelihood:                -2498.6
# No. Observations:                 578   AIC:                             5001.
# Df Residuals:                     576   BIC:                             5010.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
dfmlr=dataset[['Assessment 1','Assessment 3', 'Online quiz 1 ', 'Group assignment 2']]
IVs=dfmlr
IVs = sm.add_constant(IVs)

modelmlr=sm.OLS(dataset["Final exam"], IVs).fit()
modelmlr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Final exam   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.163
# Method:                 Least Squares   F-statistic:                     29.05
# Date:                Thu, 17 May 2018   Prob (F-statistic):           5.21e-22
# Time:                        21:05:53   Log-Likelihood:                -2474.6
# No. Observations:                 578   AIC:                             4959.
# Df Residuals:                     573   BIC:                             4981.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
predictionsmlr = modelmlr.predict(IVs)
predictionsmlr.head (5)
# Out:
# 0    28.532945
# 1    57.694505
# 2    34.711632
# 3    59.495368
# 4    50.771005
# dtype: float64

# %%
bin=[0,50,100]
dataset['Status'] = pd.cut(dataset['Total_marks'],bin, 
               labels=["Incomplete", "Complete"])
dataset['Status'].head(10)
# Out:
# 0      Complete
# 1      Complete
# 2    Incomplete
# 3      Complete
# 4    Incomplete
# 5      Complete
# 6      Complete
# 7    Incomplete
# 8    Incomplete
# 9    Incomplete
# Name: Status, dtype: category
# Categories (2, object): [Incomplete < Complete]

# %%
dataset = pd.get_dummies(dataset, columns=['Status'])
dataset.head(2)
# Out:
#    ID number  Assessment 1  Assessment 2  Online quiz 1   Online quiz 2  \
# 0   54002768         17.21         24.19             0.0           0.00
# 1   54005658         66.50          0.00            22.0          18.14
#
#    Online quiz 3  Online quiz 4  Group assignment 1  Group assignment 2  \
# 0           15.0          18.92               26.57                0.00
# 1           29.0          19.91               22.35               17.04
#
#    Assessment 3       ...         Group assignment 3   Group evaluation  \
# 0          0.00       ...                       50.0               2.00
# 1         60.54       ...                       42.5               1.88
#
#    Final exam  Class No  groupname Student category Total_marks   Grade  \
# 0          69         9     cl9tg2         domestic     57.0576    Pass
# 1          63         2     cl2tg8         domestic     70.2472  Credit
#
#   Status_Incomplete  Status_Complete
# 0                 0                1
# ...

# %%
##split the data, keeping approximately 100 people
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset['Assessment 3'], dataset['Status_Complete'], test_size=0.17)

##add a constant to logistic regression
X_train= sm.add_constant(X_train)
##run the model
modelglm = sm.Logit(y_train, X_train).fit()
modelglm.summary2()
# Out:
# Optimization terminated successfully.
#          Current function value: 33.430727
#          Iterations 6
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                          Results: Logit
# ...
# Model:              Logit            No. Iterations:   6.0000
# Dependent Variable: Status_Complete  Pseudo R-squared: -143.912
# Date:               2018-05-17 21:05 AIC:              32030.6363
# No. Observations:   479              BIC:              32038.9797
# Df Model:           1                Log-Likelihood:   -16013.
# Df Residuals:       477              LL-Null:          -110.50
# Converged:          1.0000           Scale:            1.0000
# ------------------------------------------------------------------
#                Coef.   Std.Err.     z     P>|z|    [0.025   0.975]
# ------------------------------------------------------------------
# const         -1.8292    0.3371  -5.4258  0.0000  -2.4900  -1.1685
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = logreg.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-280-1f740d008a54> in <module>()
# ----> 1 y_pred = logreg.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     322             Predicted class label per sample.
#     323         """
# --> 324         scores = self.decision_function(X)
#     325         if len(scores.shape) == 1:
#     326             indices = (scores > 0).astype(np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     298                                  "yet" % {'name': type(self).__name__})
#     299
# --> 300         X = check_array(X, accept_sparse='csr')
#     301
#     302         n_features = self.coef_.shape[1]
#
# ...

# %%
## How i would finish the assignment if i could get the previous step to work
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-281-ce754b32714f> in <module>()
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 confusion_matrix = confusion_matrix(y_test, y_pred)
#       3 print(confusion_matrix)
#
# NameError: name 'y_pred' is not defined
